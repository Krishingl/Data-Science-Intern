# %% [markdown]
# # LetsGrowMore
#
# # Name: Krushna Shrikant Ingle
#
# # Task 4:Image to Pencil Sketch with Python
#
# ### Language : Python
#
# ### IDE : Jupyter Notebook

# %% [markdown]
# ### Importing Modules

# %%
import cv2 
import matplotlib.pyplot as plt
plt.style.use('seaborn')

# %% [markdown]
# ### Loading and Plotting Original Image

# %%
#image = cv2.imread('/vansh/dora.png')/Users/vasant/Desktop/EXAM/sem7/shinchan.jpg
img = cv2.imread('K:\\Desktop\\madhura\\046ec8843e154ce285f7fc30d8c44ae6.jpg')
img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.figure(figsize=(6,6))
plt.imshow(img)
plt.axis("off")
plt.title("Original Image")
plt.show()

# %% [markdown]
# ### Converting Image to GrayScale

# %%
img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
plt.figure(figsize=(8,8))
plt.imshow(img_gray,cmap="gray")
plt.axis("off")
plt.title("GrayScale Image")
plt.show()

# %%
img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
plt.figure(figsize=(8,8))
plt.imshow(img_gray,cmap="gray")
plt.axis("off")
plt.title("GrayScale Image")
plt.show()

# %% [markdown]
# ### Inverting the Image

# %%
img_invert = cv2.bitwise_not(img_gray)
plt.figure(figsize=(8,8))
plt.imshow(img_invert,cmap="gray")
plt.axis("off")
plt.title("Inverted Image")
plt.show()

# %% [markdown]
# ### we will also be smoothing the image to make sure the sketch we obtain is less edgy and smooth

# %%
img_smoothing = cv2.GaussianBlur(img_invert, (21, 21),sigmaX=0, sigmaY=0)
plt.figure(figsize=(8,8))
plt.imshow(img_smoothing,cmap="gray")
plt.axis("off")
plt.title("Smoothen Image")
plt.show()

# %% [markdown]
# ### Converting your images to pencil sketches

# %%
final = cv2.divide(img_gray, 255 - img_smoothing, scale=255)
plt.figure(figsize=(8,8))
plt.imshow(final,cmap="gray")
plt.axis("off")
plt.title("Final Sketch Image")
plt.show()

# %% [markdown]
# ### The Final Output

# %%
plt.figure(figsize=(20,20))
plt.subplot(1,2,1)
plt.imshow(img)
plt.axis("off")
plt.title("Original Image")

plt.subplot(1,2,2)
plt.imshow(final,cmap="gray")
plt.axis("off")
plt.title("Final Sketch Image")
plt.show()

# %% [markdown]
# # Thank You
